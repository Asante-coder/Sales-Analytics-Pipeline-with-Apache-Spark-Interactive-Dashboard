# %%
pip install pyspark pandas streamlit matplotlib
# Out:
# ...
#   Using cached pyspark-4.1.1.tar.gz (455.4 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached py4j-0.10.9.9-py2.py3-none-any.whl.metadata (1.3 kB)
# ...
# Using cached py4j-0.10.9.9-py2.py3-none-any.whl (203 kB)
# ...
#   Created wheel for pyspark: filename=pyspark-4.1.1-py2.py3-none-any.whl size=456008747 sha256=3f8e568073575ed0f77c4fd4f962244ce3681453edcc9e934bdf18dc1b755ac7
#   Stored in directory: c:\users\francisasantensiah\appdata\local\pip\cache\wheels\16\33\a9\f8bff354a182417214933df74dace2a34b02c3e5643e8fac74
# Successfully built pyspark
# ...
#
#    ---------------------------------------- 0/2 [py4j]
#    ---------------------------------------- 0/2 [py4j]
# ...

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("Sales Pipeline") \
    .getOrCreate()

df = spark.read.csv("C:/Users/FrancisAsanteNsiah/Desktop/STUFF/boj/My_Project/Sales Analytics Pipeline with Apache Spark & Interactive Dashboard/data/raw/sales_data.csv", header=True, inferSchema=True)

df.printSchema()
df.show()
# Out:
# root
#  |-- order_id: integer (nullable = true)
#  |-- product: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- price: integer (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- country: string (nullable = true)
#  |-- date: date (nullable = true)
#
# +--------+------------+-----------+-----+--------+------------+----------+
# |order_id|     product|   category|price|quantity|     country|      date|
# +--------+------------+-----------+-----+--------+------------+----------+
# |    1001|      Laptop|Electronics| 1200|       2|       Ghana|2025-01-15|
# |    1002|       Phone|Electronics|  800|       3|     Nigeria|2025-01-16|
# |    1003|  Headphones|Electronics|  150|       5|       Ghana|2025-01-17|
# |    1004|        Desk|  Furniture|  300|       1|       Kenya|2025-01-18|
# |    1005|       Chair|  Furniture|  120|       4|       Ghana|2025-01-19|
# |    1006|         Pen| Stationery|    2|      50|     Nigeria|2025-01-20|
# ...
